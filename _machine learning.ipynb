# %%
import pandas as pd
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from sklearn import preprocessing 
label_encoder=preprocessing.LabelEncoder()
df['Species']=label_encoder.fit_transform(df['Species'])
df['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
actual=[1,1,0,1,0,0,1,0,0,0]
predicted=[1,0,0,1,0,0,1,1,1,0]
results=confusion_matrix(actual,predicted)
print(results)
print('Accuracy Score:',accuracy_score(actual,predicted))
print(classification_report(actual,predicted))
# Out:
# [[4 2]
#  [1 3]]
# Accuracy Score: 0.7
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73         6
#            1       0.60      0.75      0.67         4
#
#     accuracy                           0.70        10
#    macro avg       0.70      0.71      0.70        10
# weighted avg       0.72      0.70      0.70        10

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
tmp=data.drop('Id',axis=1)
g=sns.pairplot(tmp,hue='Species',markers='*')
plt.show()
# Out:
# C:\Users\saite\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\saite\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\saite\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
x=data.drop(['Id','Species'],axis=1)
y=data['Species']
print(x.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
x.head(3)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2

# %%
x.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
y.head(3)
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# Name: Species, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=5)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (90, 4)
# (90,)
# (60, 4)
# (60,)

# %%
x_train.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 60             5.0           2.0            3.5           1.0
# 147            6.5           3.0            5.2           2.0
# 104            6.5           3.0            5.8           2.2
# 52             6.9           3.1            4.9           1.5
# 22             4.6           3.6            1.0           0.2

# %%
x_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 60             5.0           2.0            3.5           1.0
# 147            6.5           3.0            5.2           2.0
# 104            6.5           3.0            5.8           2.2
# 52             6.9           3.1            4.9           1.5
# 22             4.6           3.6            1.0           0.2
# ..             ...           ...            ...           ...
# 8              4.4           2.9            1.4           0.2
# 73             6.1           2.8            4.7           1.2
# 144            6.7           3.3            5.7           2.5
# 118            7.7           2.6            6.9           2.3
# 99             5.7           2.8            4.1           1.3
#
# [90 rows x 4 columns]

# %%
y_train
# Out:
# 60     Iris-versicolor
# 147     Iris-virginica
# 104     Iris-virginica
# 52     Iris-versicolor
# 22         Iris-setosa
#             ...
# 8          Iris-setosa
# 73     Iris-versicolor
# 144     Iris-virginica
# 118     Iris-virginica
# 99     Iris-versicolor
# Name: Species, Length: 90, dtype: object

# %%
x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 82             5.8           2.7            3.9           1.2
# 134            6.1           2.6            5.6           1.4
# 114            5.8           2.8            5.1           2.4
# 42             4.4           3.2            1.3           0.2
# 109            7.2           3.6            6.1           2.5
# 57             4.9           2.4            3.3           1.0
# 1              4.9           3.0            1.4           0.2
# 70             5.9           3.2            4.8           1.8
# 25             5.0           3.0            1.6           0.2
# 84             5.4           3.0            4.5           1.5
# 66             5.6           3.0            4.5           1.5
# 133            6.3           2.8            5.1           1.5
# 102            7.1           3.0            5.9           2.1
# 107            7.3           2.9            6.3           1.8
# ...

# %%
y_test
# Out:
# 82     Iris-versicolor
# 134     Iris-virginica
# 114     Iris-virginica
# 42         Iris-setosa
# 109     Iris-virginica
# 57     Iris-versicolor
# 1          Iris-setosa
# 70     Iris-versicolor
# 25         Iris-setosa
# 84     Iris-versicolor
# 66     Iris-versicolor
# 133     Iris-virginica
# 102     Iris-virginica
# 107     Iris-virginica
# 26         Iris-setosa
# 23         Iris-setosa
# 123     Iris-virginica
# 130     Iris-virginica
# 21         Iris-setosa
# 12         Iris-setosa
# 71     Iris-versicolor
# 128     Iris-virginica
# 48         Iris-setosa
# 72     Iris-versicolor
# 88     Iris-versicolor
# 148     Iris-virginica
# 74     Iris-versicolor
# 96     Iris-versicolor
# 63     Iris-versicolor
# 132     Iris-virginica
# 39         Iris-setosa
# 53     Iris-versicolor
# 79     Iris-versicolor
# 10         Iris-setosa
# 50     Iris-versicolor
# 49         Iris-setosa
# 43         Iris-setosa
# 135     Iris-virginica
# 40         Iris-setosa
# 115     Iris-virginica
# ...

# %%
knn=KNeighborsClassifier(n_neighbors=12)
knn.fit(x_train,y_train)
knn.predict([[2.1,8.9,5.6,4.0]])
# Out:
# C:\Users\saite\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Iris-virginica'], dtype=object)

# %%
y_pred=knn.predict(x_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.9833333333333333

# %%
data=pd.read_csv('diabetes.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 790           10      101             76             48      180  32.9
# 791            2      122             70             27        0  36.8
# 792            5      121             72             23      112  26.2
# 793            1      126             60              0        0  30.1
# 794            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
x=data.drop(['Pregnancies','BMI', 'DiabetesPedigreeFunction','Age','Outcome'],axis=1)
y=data['Outcome']
print(x.shape)
print(y.shape)
# Out:
# (795, 4)
# (795,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=5)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (477, 4)
# (477,)
# (318, 4)
# (318,)

# %%
knn=KNeighborsClassifier(n_neighbors=12)
knn.fit(x_train,y_train)
knn.predict([[5,30,0.5,50]])
# Out:
# C:\Users\saite\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
from sklearn import preprocessing
scaler=preprocessing.StandardScaler()
scaled_data=pd.DataFrame(scaler.fit_transform(x))
scaled_data
# Out:
#             0         1         2         3
# 0    0.834845  0.151414  0.909277 -0.680792
# 1   -1.130986 -0.155794  0.534147 -0.680792
# 2    1.926974 -0.258196 -1.278980 -0.680792
# 3   -1.006171 -0.155794  0.159017  0.112837
# 4    0.491605 -1.487029  0.909277  0.737609
# ..        ...       ...       ...       ...
# 790 -0.631727  0.356220  1.722058  0.838923
# 791  0.023550  0.049012  0.409104 -0.680792
# 792 -0.007654  0.151414  0.159017  0.264808
# 793  0.148365 -0.463002 -1.278980 -0.680792
# 794 -0.881357  0.049012  0.659190 -0.680792
#
# [795 rows x 4 columns]

# %%
scaled_data.colums={'sepal length','sepal width','petal length','petal width'}
scaled_data
# Out:
# C:\Users\saite\AppData\Local\Temp\ipykernel_29380\3896450912.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   scaled_data.colums={'sepal length','sepal width','petal length','petal width'}
#             0         1         2         3
# 0    0.834845  0.151414  0.909277 -0.680792
# 1   -1.130986 -0.155794  0.534147 -0.680792
# 2    1.926974 -0.258196 -1.278980 -0.680792
# 3   -1.006171 -0.155794  0.159017  0.112837
# 4    0.491605 -1.487029  0.909277  0.737609
# ..        ...       ...       ...       ...
# 790 -0.631727  0.356220  1.722058  0.838923
# 791  0.023550  0.049012  0.409104 -0.680792
# 792 -0.007654  0.151414  0.159017  0.264808
# 793  0.148365 -0.463002 -1.278980 -0.680792
# 794 -0.881357  0.049012  0.659190 -0.680792
#
# [795 rows x 4 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(scaled_data,y,test_size=0.4,random_state=5)

# %%
x_train.head(5)
# Out:
#             0         1         2         3
# 115  0.460401  0.049012  0.721712  0.247923
# 773  0.803642  1.277844  1.284406 -0.680792
# 189 -0.226079  0.561025  0.846755  1.725423
# 116 -0.444505 -0.053391 -0.091069 -0.680792
# 326 -0.288487  0.151414 -1.278980 -0.680792

# %%
y_train.head(5)
# Out:
# 115    1
# 773    1
# 189    0
# 116    0
# 326    0
# Name: Outcome, dtype: int64
